# %% [markdown]
# # Life Expectancy vs Crime Rate
# ---
# Is there a clear correlation between Life Expectancy and Crime Rate? Intuitively this seems true but is there any data confirming this statement? Let's find out!

# %% [markdown]
# ## Life Expectancy
#
# First, we will load population indicators data (which includes life expectancy) from the United Nations Statistics Division (__http://data.un.org/_Docs/SYB/CSV/SYB60_T03_Population%20Growth,%20Fertility%20and%20Mortality%20Indicators.csv__) into a pandas dataframe.

# %%
import pandas as pd
import os

filename = os.path.join('Data', 'SYB60_T03_Population Growth_Fertility_and_Mortality_Indicators.csv')
population_indicators_df = pd.read_csv(filename, encoding='ISO-8859-1', skiprows=1, thousands=',')
population_indicators_df
population_indicators_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                                         'Unnamed: 1': 'Region/Country/Area'}, inplace=True)

population_indicators_df = population_indicators_df[564:]  # remove data per region and just keep data per country
population_indicators_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                                         'Region/Country/Area': 'Country'}, inplace=True)
#population_indicators_df
population_indicators_df.head()
# Out:
#      Country ID      Country  Year  \
# 564           4  Afghanistan  2005
# 565           4  Afghanistan  2005
# 566           4  Afghanistan  2005
# 567           4  Afghanistan  2005
# 568           4  Afghanistan  2005
#
#                                                 Series  Value  \
# 564       Population annual rate of increase (percent)    4.4
# 565          Total fertility rate (children per women)    7.2
# 566  Infant mortality for both sexes (per 1,000 liv...   89.5
# 567  Maternal mortality ratio (deaths per 100,000 p...  821.0
# 568    Life expectancy at birth for both sexes (years)   56.9
#
#                                              Footnotes  \
# 564  Data refers to a 5-year period preceding the r...
# 565  Data refers to a 5-year period preceding the r...
# 566  Data refers to a 5-year period preceding the r...
# 567                                                NaN
# 568  Data refers to a 5-year period preceding the r...
#
#                                                 Source
# 564  United Nations Population Division, New York, ...
# 565  United Nations Population Division, New York, ...
# 566  United Nations Statistics Division, New York, ...
# 567  World Health Organization (WHO), the United Na...
# 568  United Nations Population Division, New York, ...

# %% [markdown]
# ## Crime Rate
#
# As a second step, we will load Crime Rate data obtained from the United Nations Statistics Division (__http://data.un.org/_Docs/SYB/CSV/SYB62_T12_201904_Intentional%20homicides%20and%20Other%20Crimes.csv__) into a pandas dataframe.

# %%
import pandas as pd
import os

filename = os.path.join('Data', 'SYB62_T12_201904_Intentional homicides and Other Crimes.csv')
crime_df = pd.read_csv(filename, encoding='ISO-8859-1', skiprows=1, thousands=',')
crime_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                         'Unnamed: 1': 'Region/Country/Area'}, inplace=True)
crime_df = crime_df[6:]            # remove data per region and just keep data per country
crime_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                         'Region/Country/Area': 'Country'}, inplace=True)
crime_df.head()
# Out:
#     Country ID      Country  Year  \
# 6            4  Afghanistan  2010
# 7            4  Afghanistan  2012
# 8            4  Afghanistan  2012
# 9            4  Afghanistan  2012
# 10           8      Albania  2005
#
#                                                Series  Value  Footnotes  \
# 6              Intentional homicide rates per 100,000    3.4        NaN
# 7              Intentional homicide rates per 100,000    6.3        NaN
# 8   Percentage of male and female intentional homi...   11.8  Estimate.
# 9   Percentage of male and female intentional homi...    0.6  Estimate.
# 10             Intentional homicide rates per 100,000    5.0        NaN
#
#                                                Source
# 6   United Nations Office on Drugs and Crime (UNOD...
# 7   United Nations Office on Drugs and Crime (UNOD...
# 8   United Nations Office on Drugs and Crime (UNOD...
# 9   United Nations Office on Drugs and Crime (UNOD...
# 10  United Nations Office on Drugs and Crime (UNOD...

# %%
# after inspecting the data above, it seems that intentional homicide rates per 100,000 is measured
# in most of the countries... we will use that first

crime_df_2010 = crime_df[crime_df['Year']==2010]
crime_df_2010.pivot(index='Country', columns='Series', values='Value')#.dropna(axis='index')
# Out:
# Series                        Assault rate per 100,000 population  \
# Country
# Afghanistan                                                   NaN
# Albania                                                       6.1
# Algeria                                                     114.6
# American Samoa                                                NaN
# Andorra                                                     116.0
# Antigua and Barbuda                                           NaN
# Armenia                                                       5.4
# Aruba                                                         NaN
# Australia                                                   310.4
# Austria                                                      42.9
# Azerbaijan                                                    1.9
# Bahamas                                                     848.9
# Bahrain                                                       NaN
# Bangladesh                                                    NaN
# Barbados                                                    540.5
# Belarus                                                      12.2
# Belgium                                                     710.8
# Belize                                                        NaN
# Benin                                                         NaN
# Bermuda                                                     964.7
# Bhutan                                                        9.2
# Bolivia (Plurin. State of)                                   85.2
# Bosnia and Herzegovina                                       13.6
# Botswana                                                    866.4
# Brazil                                                      363.7
# Brunei Darussalam                                             NaN
# Bulgaria                                                     41.0
# Burkina Faso                                                  NaN
# Burundi                                                       3.5
# Cabo Verde                                                  814.1
# ...                                                           ...
# South Africa                                                  NaN
# Spain                                                        53.6
# Sri Lanka                                                   319.9
# State of Palestine                                            7.0
# Sweden                                                       59.6
# Switzerland                                                   6.2
# Syrian Arab Republic                                          NaN
# Tajikistan                                                   71.8
# Thailand                                                     13.6
# Timor-Leste                                                   NaN
# Togo                                                          NaN
# Tonga                                                         NaN
# Trinidad and Tobago                                          46.4
# Tunisia                                                       NaN
# Turkey                                                      305.4
# Tuvalu                                                        NaN
# Uganda                                                       67.8
# Ukraine                                                       8.8
# United Arab Emirates                                          NaN
# United Kingdom                                              658.8
# United Rep. of Tanzania                                       NaN
# United States Virgin Islands                                  NaN
# United States of America                                    253.3
# Uruguay                                                      15.4
# Vanuatu                                                       NaN
# Venezuela (Boliv. Rep. of)                                    NaN
# Viet Nam                                                      NaN
# Yemen                                                         NaN
# Zambia                                                        NaN
# Zimbabwe                                                      NaN
#
# Series                        Intentional homicide rates per 100,000  \
# Country
# Afghanistan                                                      3.4
# Albania                                                          4.3
# Algeria                                                          0.7
# American Samoa                                                   9.0
# Andorra                                                          NaN
# Antigua and Barbuda                                              6.3
# Armenia                                                          1.9
# Aruba                                                            3.9
# Australia                                                        1.0
# Austria                                                          0.7
# Azerbaijan                                                       2.3
# Bahamas                                                         26.1
# Bahrain                                                          0.9
# Bangladesh                                                       2.6
# Barbados                                                        11.1
# Belarus                                                          4.2
# Belgium                                                          1.7
# Belize                                                          40.1
# Benin                                                            6.6
# Bermuda                                                         10.9
# Bhutan                                                           2.2
# Bolivia (Plurin. State of)                                      12.8
# Bosnia and Herzegovina                                           1.5
# Botswana                                                        15.0
# Brazil                                                          22.0
# Brunei Darussalam                                                0.3
# Bulgaria                                                         2.0
# Burkina Faso                                                     0.6
# Burundi                                                          4.0
# Cabo Verde                                                       7.8
# ...                                                              ...
# South Africa                                                    30.8
# Spain                                                            0.9
# Sri Lanka                                                        3.8
# State of Palestine                                               0.8
# Sweden                                                           1.0
# Switzerland                                                      0.7
# Syrian Arab Republic                                             2.2
# Tajikistan                                                       2.4
# Thailand                                                         5.4
# Timor-Leste                                                      3.5
# Togo                                                             9.6
# Tonga                                                            1.0
# Trinidad and Tobago                                             35.6
# Tunisia                                                          2.7
# Turkey                                                           4.2
# Tuvalu                                                           9.5
# Uganda                                                           9.3
# Ukraine                                                          4.3
# United Arab Emirates                                             0.8
# United Kingdom                                                   1.2
# United Rep. of Tanzania                                          8.4
# United States Virgin Islands                                    52.8
# United States of America                                         4.8
# Uruguay                                                          6.1
# Vanuatu                                                          2.3
# Venezuela (Boliv. Rep. of)                                      45.1
# Viet Nam                                                         1.5
# Yemen                                                            4.7
# Zambia                                                           5.9
# Zimbabwe                                                         5.0
#
# Series                        Kidnapping at the national level, rate per 100,000  \
# Country
# Afghanistan                                                                 NaN
# Albania                                                                     0.3
# Algeria                                                                     0.5
# American Samoa                                                              NaN
# Andorra                                                                     NaN
# Antigua and Barbuda                                                         NaN
# Armenia                                                                     1.4
# Aruba                                                                       NaN
# Australia                                                                   2.8
# Austria                                                                     0.1
# Azerbaijan                                                                  0.0
# Bahamas                                                                     5.0
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                    4.3
# Belarus                                                                     0.2
# Belgium                                                                    10.3
# Belize                                                                      NaN
# Benin                                                                       NaN
# Bermuda                                                                     1.6
# Bhutan                                                                      0.1
# Bolivia (Plurin. State of)                                                  0.9
# Bosnia and Herzegovina                                                      0.0
# Botswana                                                                    0.1
# Brazil                                                                      0.2
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                    1.6
# Burkina Faso                                                                NaN
# Burundi                                                                     0.3
# Cabo Verde                                                                  1.2
# ...                                                                         ...
# South Africa                                                                NaN
# Spain                                                                       0.3
# Sri Lanka                                                                   1.0
# State of Palestine                                                          0.5
# Sweden                                                                      NaN
# Switzerland                                                                 0.0
# Syrian Arab Republic                                                        NaN
# Tajikistan                                                                  1.9
# Thailand                                                                    0.0
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       NaN
# Trinidad and Tobago                                                         0.5
# Tunisia                                                                     NaN
# Turkey                                                                     18.8
# Tuvalu                                                                      NaN
# Uganda                                                                      0.4
# Ukraine                                                                     0.6
# United Arab Emirates                                                        NaN
# United Kingdom                                                              3.1
# United Rep. of Tanzania                                                     0.0
# United States Virgin Islands                                                NaN
# United States of America                                                    NaN
# Uruguay                                                                     NaN
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                  NaN
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# Series                        Percentage of male and female intentional homicide victims, Female  \
# Country
# Afghanistan                                                                 NaN
# Albania                                                                     1.3
# Algeria                                                                     NaN
# American Samoa                                                              NaN
# Andorra                                                                     0.0
# Antigua and Barbuda                                                         NaN
# Armenia                                                                     0.7
# Aruba                                                                       0.0
# Australia                                                                   0.8
# Austria                                                                     0.7
# Azerbaijan                                                                  1.4
# Bahamas                                                                     7.6
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                    5.5
# Belarus                                                                     2.7
# Belgium                                                                     1.2
# Belize                                                                     10.0
# Benin                                                                       NaN
# Bermuda                                                                     0.0
# Bhutan                                                                      NaN
# Bolivia (Plurin. State of)                                                  NaN
# Bosnia and Herzegovina                                                      0.5
# Botswana                                                                    2.5
# Brazil                                                                      3.7
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                    0.7
# Burkina Faso                                                                NaN
# Burundi                                                                     NaN
# Cabo Verde                                                                  NaN
# ...                                                                         ...
# South Africa                                                               10.4
# Spain                                                                       0.7
# Sri Lanka                                                                   1.6
# State of Palestine                                                          0.5
# Sweden                                                                      0.6
# Switzerland                                                                 0.7
# Syrian Arab Republic                                                        1.0
# Tajikistan                                                                  0.6
# Thailand                                                                    1.3
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       0.0
# Trinidad and Tobago                                                         7.9
# Tunisia                                                                     NaN
# Turkey                                                                      1.7
# Tuvalu                                                                      NaN
# Uganda                                                                      3.5
# Ukraine                                                                     2.4
# United Arab Emirates                                                        0.9
# United Kingdom                                                              0.9
# United Rep. of Tanzania                                                     2.4
# United States Virgin Islands                                               12.6
# United States of America                                                    2.1
# Uruguay                                                                     2.3
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                  5.4
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# Series                        Percentage of male and female intentional homicide victims, Male  \
# Country
# Afghanistan                                                                 NaN
# Albania                                                                     7.3
# Algeria                                                                     NaN
# American Samoa                                                              NaN
# Andorra                                                                     0.0
# Antigua and Barbuda                                                         NaN
# Armenia                                                                     3.4
# Aruba                                                                       8.3
# Australia                                                                   1.2
# Austria                                                                     0.7
# Azerbaijan                                                                  3.2
# Bahamas                                                                    45.4
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                   17.1
# Belarus                                                                     6.0
# Belgium                                                                     2.2
# Belize                                                                     70.2
# Benin                                                                       NaN
# Bermuda                                                                    23.0
# Bhutan                                                                      NaN
# Bolivia (Plurin. State of)                                                  NaN
# Bosnia and Herzegovina                                                      2.5
# Botswana                                                                   27.9
# Brazil                                                                     40.8
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                    3.4
# Burkina Faso                                                                NaN
# Burundi                                                                     NaN
# Cabo Verde                                                                  NaN
# ...                                                                         ...
# South Africa                                                               51.9
# Spain                                                                       1.1
# Sri Lanka                                                                   6.1
# State of Palestine                                                          1.1
# Sweden                                                                      1.4
# Switzerland                                                                 0.7
# Syrian Arab Republic                                                        3.4
# Tajikistan                                                                  4.1
# Thailand                                                                    9.7
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       1.9
# Trinidad and Tobago                                                        63.9
# Tunisia                                                                     NaN
# Turkey                                                                      6.8
# Tuvalu                                                                      NaN
# Uganda                                                                     15.2
# Ukraine                                                                     6.6
# United Arab Emirates                                                        0.8
# United Kingdom                                                              1.5
# United Rep. of Tanzania                                                    14.7
# United States Virgin Islands                                               96.5
# United States of America                                                    7.5
# Uruguay                                                                    10.1
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                 84.8
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# Series                        Robbery at the national level, rate per 100,000 population  \
# Country
# Afghanistan                                                                 NaN
# Albania                                                                     8.0
# Algeria                                                                    51.2
# American Samoa                                                              NaN
# Andorra                                                                     9.5
# Antigua and Barbuda                                                         NaN
# Armenia                                                                    12.4
# Aruba                                                                       NaN
# Australia                                                                  66.2
# Austria                                                                    51.2
# Azerbaijan                                                                  3.3
# Bahamas                                                                    93.1
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                  174.2
# Belarus                                                                    50.0
# Belgium                                                                   218.1
# Belize                                                                    148.3
# Benin                                                                       NaN
# Bermuda                                                                   154.8
# Bhutan                                                                      6.5
# Bolivia (Plurin. State of)                                                125.7
# Bosnia and Herzegovina                                                      NaN
# Botswana                                                                  119.3
# Brazil                                                                    549.3
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                   50.5
# Burkina Faso                                                                NaN
# Burundi                                                                    34.7
# Cabo Verde                                                                611.9
# ...                                                                         ...
# South Africa                                                                NaN
# Spain                                                                     180.4
# Sri Lanka                                                                  31.9
# State of Palestine                                                         69.9
# Sweden                                                                     98.2
# Switzerland                                                                56.3
# Syrian Arab Republic                                                        NaN
# Tajikistan                                                                  3.2
# Thailand                                                                    2.7
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       NaN
# Trinidad and Tobago                                                       385.7
# Tunisia                                                                     NaN
# Turkey                                                                     11.9
# Tuvalu                                                                      NaN
# Uganda                                                                     17.8
# Ukraine                                                                    50.9
# United Arab Emirates                                                        NaN
# United Kingdom                                                            136.8
# United Rep. of Tanzania                                                    25.8
# United States Virgin Islands                                                NaN
# United States of America                                                  119.6
# Uruguay                                                                   409.8
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                  NaN
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# Series                        Theft at the national level, rate per 100,000 population  \
# Country
# Afghanistan                                                                 NaN
# Albania                                                                   135.3
# Algeria                                                                   141.4
# American Samoa                                                              NaN
# Andorra                                                                  1322.7
# Antigua and Barbuda                                                         NaN
# Armenia                                                                   127.3
# Aruba                                                                       NaN
# Australia                                                                2157.6
# Austria                                                                  1853.2
# Azerbaijan                                                                 42.8
# Bahamas                                                                   545.7
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                  739.4
# Belarus                                                                   776.8
# Belgium                                                                  2087.6
# Belize                                                                    259.9
# Benin                                                                       NaN
# Bermuda                                                                   950.7
# Bhutan                                                                     67.2
# Bolivia (Plurin. State of)                                                 50.9
# Bosnia and Herzegovina                                                    305.3
# Botswana                                                                 1474.8
# Brazil                                                                    702.6
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                  681.7
# Burkina Faso                                                                NaN
# Burundi                                                                     NaN
# Cabo Verde                                                                746.6
# ...                                                                         ...
# South Africa                                                                NaN
# Spain                                                                     309.1
# Sri Lanka                                                                  62.8
# State of Palestine                                                         67.4
# Sweden                                                                   3918.6
# Switzerland                                                              2059.2
# Syrian Arab Republic                                                        NaN
# Tajikistan                                                                 46.6
# Thailand                                                                   80.8
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       NaN
# Trinidad and Tobago                                                       307.9
# Tunisia                                                                     NaN
# Turkey                                                                    248.3
# Tuvalu                                                                      NaN
# Uganda                                                                     69.1
# Ukraine                                                                   556.3
# United Arab Emirates                                                        NaN
# United Kingdom                                                           2654.9
# United Rep. of Tanzania                                                     NaN
# United States Virgin Islands                                                NaN
# United States of America                                                 2010.3
# Uruguay                                                                  2823.3
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                  NaN
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# Series                        Total Sexual Violence at the national level, rate per 100,000
# Country
# Afghanistan                                                                 NaN
# Albania                                                                     2.7
# Algeria                                                                    10.5
# American Samoa                                                              NaN
# Andorra                                                                    11.9
# Antigua and Barbuda                                                         NaN
# Armenia                                                                     2.8
# Aruba                                                                       NaN
# Australia                                                                  85.1
# Austria                                                                    39.3
# Azerbaijan                                                                  2.2
# Bahamas                                                                    85.6
# Bahrain                                                                     NaN
# Bangladesh                                                                  NaN
# Barbados                                                                   60.5
# Belarus                                                                     3.9
# Belgium                                                                    64.9
# Belize                                                                     40.4
# Benin                                                                       NaN
# Bermuda                                                                   143.9
# Bhutan                                                                      9.9
# Bolivia (Plurin. State of)                                                 39.8
# Bosnia and Herzegovina                                                      3.8
# Botswana                                                                    NaN
# Brazil                                                                     23.4
# Brunei Darussalam                                                           NaN
# Bulgaria                                                                    9.4
# Burkina Faso                                                                NaN
# Burundi                                                                     7.4
# Cabo Verde                                                                 41.4
# ...                                                                         ...
# South Africa                                                                NaN
# Spain                                                                      21.4
# Sri Lanka                                                                   4.4
# State of Palestine                                                          4.4
# Sweden                                                                    150.6
# Switzerland                                                                31.8
# Syrian Arab Republic                                                        NaN
# Tajikistan                                                                  2.6
# Thailand                                                                    2.9
# Timor-Leste                                                                 NaN
# Togo                                                                        NaN
# Tonga                                                                       NaN
# Trinidad and Tobago                                                        57.8
# Tunisia                                                                     NaN
# Turkey                                                                      5.8
# Tuvalu                                                                      NaN
# Uganda                                                                     26.1
# Ukraine                                                                     3.0
# United Arab Emirates                                                        NaN
# United Kingdom                                                             81.5
# United Rep. of Tanzania                                                     0.0
# United States Virgin Islands                                                NaN
# United States of America                                                    NaN
# Uruguay                                                                     NaN
# Vanuatu                                                                     NaN
# Venezuela (Boliv. Rep. of)                                                  NaN
# Viet Nam                                                                    NaN
# Yemen                                                                       NaN
# Zambia                                                                      NaN
# Zimbabwe                                                                    NaN
#
# [193 rows x 8 columns]

# %% [markdown]
# ## Population
#
# As a third step, we will load population data per country
# from the United Nations Statistics Division (__http://data.un.org/_Docs/SYB/CSV/SYB61_T02_Population,%20Surface%20Area%20and%20Density.csv__) into a pandas dataframe.

# %%
filename = os.path.join('Data', 'SYB61_T02_Population, Surface Area and Density.csv')
population_df = pd.read_csv(filename, encoding='ISO-8859-1', skiprows=1, thousands=',')
population_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                             'Unnamed: 1': 'Region/Country/Area'}, inplace=True)
population_df = population_df[899:]      # remove data per region and just keep data per country
population_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                              'Region/Country/Area': 'Country'}, inplace=True)
population_df.head()
# Out:
#      Country ID      Country  Year  \
# 899           4  Afghanistan  2005
# 900           4  Afghanistan  2005
# 901           4  Afghanistan  2005
# 902           4  Afghanistan  2005
# 903           4  Afghanistan  2005
#
#                                                 Series   Value Footnotes  \
# 899           Population mid-year estimates (millions)   25.07       NaN
# 900  Population mid-year estimates for males (milli...   12.97       NaN
# 901  Population mid-year estimates for females (mil...   12.10       NaN
# 902                  Sex ratio (males per 100 females)  107.20       NaN
# 903     Population aged 0 to 14 years old (percentage)   47.60       NaN
#
#                                                 Source
# 899  United Nations Population Division, New York, ...
# 900  United Nations Population Division, New York, ...
# 901  United Nations Population Division, New York, ...
# 902  United Nations Population Division, New York, ...
# 903  United Nations Population Division, New York, ...

# %% [markdown]
# ## Putting It All Together
#
# Now, let's put all together and use different crime data variables as independent variables.

# %% [markdown]
# ## Life Expectancy vs Homicide Rates per 100,000
#
# Let's plot Life Expectancy vs Homicide Rates using a scatter plot with a bubble size set to country.

# %%
import matplotlib.pyplot as plt

homicides_df = crime_df[crime_df['Series'] == 'Intentional homicide rates per 100,000']
homicides_df = homicides_df.loc[:, ['Country', 'Year', 'Value']]
homicides_df.rename(columns={'Value': 'Intentional homicide rates per 100,000'}, inplace=True)
homicides_df.set_index(['Country', 'Year'], inplace=True)

life_expectancy_df = population_indicators_df[population_indicators_df['Series'] == 'Life expectancy at birth for both sexes (years)']
life_expectancy_df = life_expectancy_df.loc[:, ['Country', 'Year', 'Value']]
life_expectancy_df.rename(columns={'Value': 'Life expectancy at birth for both sexes (years)'}, inplace=True)
life_expectancy_df.set_index(['Country', 'Year'], inplace=True)

estimated_population_df = population_df[population_df['Series'] == 'Population mid-year estimates (millions)']
estimated_population_df = estimated_population_df.loc[:, ['Country', 'Year', 'Value']]
estimated_population_df.rename(columns={'Value': 'Population mid-year estimates (millions)'}, inplace=True)
estimated_population_df.set_index(['Country', 'Year'], inplace=True)

summary_df = homicides_df.join(life_expectancy_df, how='inner')
summary_df = summary_df.join(estimated_population_df, how='inner')
summary_df.reset_index(inplace=True)

fig, ax = plt.subplots()
ax.scatter(y=summary_df[summary_df['Year'] == 2005]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2005]['Intentional homicide rates per 100,000'],
           s=summary_df[summary_df['Year'] == 2005]['Population mid-year estimates (millions)'],
           color='yellow', marker='o', edgecolor='black', label='2005')
ax.scatter(y=summary_df[summary_df['Year'] == 2010]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2010]['Intentional homicide rates per 100,000'],
           s=summary_df[summary_df['Year'] == 2010]['Population mid-year estimates (millions)'],
           color='red', marker='o', edgecolor='black', label='2010')
ax.scatter(y=summary_df[summary_df['Year'] == 2015]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2015]['Intentional homicide rates per 100,000'],
           s=summary_df[summary_df['Year'] == 2015]['Population mid-year estimates (millions)'],
           color='orange', marker='o', edgecolor='black', label='2015')
ax.set_title('Life Expectancy vs Crime Rate\n(Note: Bubble Size Indicates Country Population)')
ax.set_xlabel('Intentional homicide rates per 100,000')
ax.set_ylabel('Life expectancy at birth (years)')
ax.set_xlim(0, 40)
lgnd = plt.legend(loc='upper right')
lgnd.legendHandles[0]._sizes = [40]
lgnd.legendHandles[1]._sizes = [40]
lgnd.legendHandles[2]._sizes = [40]
fig.set_size_inches(16.5, 10.5)
plt.grid()

# %% [markdown]
# ## Life Expectancy vs Assault Rates per 100,000
#
# Let's plot Life Expectancy vs Assault Rates using a scatter plot with a bubble size set to country.

# %%
import matplotlib.pyplot as plt

assaults_df = crime_df[crime_df['Series'] == 'Assault rate per 100,000 population']
assaults_df = assaults_df.loc[:, ['Country', 'Year', 'Value']]
assaults_df.rename(columns={'Value': 'Assault rate per 100,000 population'}, inplace=True)
assaults_df.set_index(['Country', 'Year'], inplace=True)

life_expectancy_df = population_indicators_df[population_indicators_df['Series'] == 'Life expectancy at birth for both sexes (years)']
life_expectancy_df = life_expectancy_df.loc[:, ['Country', 'Year', 'Value']]
life_expectancy_df.rename(columns={'Value': 'Life expectancy at birth for both sexes (years)'}, inplace=True)
life_expectancy_df.set_index(['Country', 'Year'], inplace=True)

estimated_population_df = population_df[population_df['Series'] == 'Population mid-year estimates (millions)']
estimated_population_df = estimated_population_df.loc[:, ['Country', 'Year', 'Value']]
estimated_population_df.rename(columns={'Value': 'Population mid-year estimates (millions)'}, inplace=True)
estimated_population_df.set_index(['Country', 'Year'], inplace=True)

summary_df = assaults_df.join(life_expectancy_df, how='inner')
summary_df = summary_df.join(estimated_population_df, how='inner')
summary_df.reset_index(inplace=True)

fig, ax = plt.subplots()
ax.scatter(y=summary_df[summary_df['Year'] == 2005]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2005]['Assault rate per 100,000 population'],
           s=summary_df[summary_df['Year'] == 2005]['Population mid-year estimates (millions)'],
           color='yellow', marker='o', edgecolor='black', label='2005')
ax.scatter(y=summary_df[summary_df['Year'] == 2010]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2010]['Assault rate per 100,000 population'],
           s=summary_df[summary_df['Year'] == 2010]['Population mid-year estimates (millions)'],
           color='red', marker='o', edgecolor='black', label='2010')
ax.scatter(y=summary_df[summary_df['Year'] == 2015]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2015]['Assault rate per 100,000 population'],
           s=summary_df[summary_df['Year'] == 2015]['Population mid-year estimates (millions)'],
           color='orange', marker='o', edgecolor='black', label='2015')
ax.set_title('Life Expectancy vs Crime Rate\n(Note: Bubble Size Indicates Country Population)')
ax.set_xlabel('Assault rate per 100,000 population')
ax.set_ylabel('Life expectancy at birth (years)')
ax.set_xlim(-25)
lgnd = plt.legend(loc='upper right')
lgnd.legendHandles[0]._sizes = [40]
lgnd.legendHandles[1]._sizes = [40]
lgnd.legendHandles[2]._sizes = [40]
fig.set_size_inches(16.5, 10.5)
plt.grid()

# %% [markdown]
# ## Educational Attainment
#
# In this step, we will load educational data per country from the United Nations Statistics Division (__http://data.un.org/_Docs/SYB/CSV/SYB62_T07_Education.csv__) into a pandas dataframe.

# %%
filename = os.path.join('Data', 'SYB61_T02_Population, Surface Area and Density.csv')
population_df = pd.read_csv(filename, encoding='ISO-8859-1', skiprows=1, thousands=',')
population_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                             'Unnamed: 1': 'Region/Country/Area'}, inplace=True)
population_df = population_df[899:]      # remove data per region and just keep data per country
population_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                              'Region/Country/Area': 'Country'}, inplace=True)
population_df.head()
# Out:
#      Country ID      Country  Year  \
# 899           4  Afghanistan  2005
# 900           4  Afghanistan  2005
# 901           4  Afghanistan  2005
# 902           4  Afghanistan  2005
# 903           4  Afghanistan  2005
#
#                                                 Series   Value Footnotes  \
# 899           Population mid-year estimates (millions)   25.07       NaN
# 900  Population mid-year estimates for males (milli...   12.97       NaN
# 901  Population mid-year estimates for females (mil...   12.10       NaN
# 902                  Sex ratio (males per 100 females)  107.20       NaN
# 903     Population aged 0 to 14 years old (percentage)   47.60       NaN
#
#                                                 Source
# 899  United Nations Population Division, New York, ...
# 900  United Nations Population Division, New York, ...
# 901  United Nations Population Division, New York, ...
# 902  United Nations Population Division, New York, ...
# 903  United Nations Population Division, New York, ...

# %% [markdown]
# ## Life Expectancy vs Educational Attainment (Tertiary)
#
# Let's plot Life Expectancy vs Educational Attainment using a scatter plot with a bubble size set to country.

# %%
import numpy as np
import matplotlib.pyplot as plt

students_in_tertiary_df = education_df[education_df['Series'] == 'Students enrolled in tertiary education (thousands)']
students_in_tertiary_df = students_in_tertiary_df.loc[:, ['Country', 'Year', 'Value']]
students_in_tertiary_df.rename(columns={'Value': 'Students enrolled in tertiary education (thousands)'}, inplace=True)
students_in_tertiary_df.set_index(['Country', 'Year'], inplace=True)

life_expectancy_df = population_indicators_df[population_indicators_df['Series'] == 'Life expectancy at birth for both sexes (years)']
life_expectancy_df = life_expectancy_df.loc[:, ['Country', 'Year', 'Value']]
life_expectancy_df.rename(columns={'Value': 'Life expectancy at birth for both sexes (years)'}, inplace=True)
life_expectancy_df.set_index(['Country', 'Year'], inplace=True)

estimated_population_df = population_df[population_df['Series'] == 'Population mid-year estimates (millions)']
estimated_population_df = estimated_population_df.loc[:, ['Country', 'Year', 'Value']]
estimated_population_df.rename(columns={'Value': 'Population mid-year estimates (millions)'}, inplace=True)
estimated_population_df.set_index(['Country', 'Year'], inplace=True)

summary_df = students_in_tertiary_df.join(life_expectancy_df, how='inner')
summary_df = summary_df.join(estimated_population_df, how='inner')
summary_df.reset_index(inplace=True)
summary_df['Students enrolled in tertiary education (thousands)'] = summary_df['Students enrolled in tertiary education (thousands)'].transform(lambda x: x.replace(',', '')).apply(pd.to_numeric).map("{:.0f}".format)


min_x = int(summary_df.sort_values("Students enrolled in tertiary education (thousands)").iloc[0]["Students enrolled in tertiary education (thousands)"])
max_x = int(summary_df.sort_values("Students enrolled in tertiary education (thousands)").iloc[-2]["Students enrolled in tertiary education (thousands)"])


fig, ax = plt.subplots()

ax.scatter(y=summary_df[summary_df['Year'] == 2005]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2005]['Students enrolled in tertiary education (thousands)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2005]['Population mid-year estimates (millions)']*7,
           color='yellow', marker='o', edgecolor='black', label='2005')
ax.scatter(y=summary_df[summary_df['Year'] == 2010]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2010]['Students enrolled in tertiary education (thousands)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2010]['Population mid-year estimates (millions)']*7,
           color='red', marker='o', edgecolor='black', label='2010')
ax.scatter(y=summary_df[summary_df['Year'] == 2015]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2015]['Students enrolled in tertiary education (thousands)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2015]['Population mid-year estimates (millions)']*7,
           color='orange', marker='o', edgecolor='black', label='2015')

ax.set_title('Life Expectancy vs Educational Attainment\n(Note: Bubble Size Indicates Country Population)')
ax.set_xlabel('Students enrolled in tertiary education (thousands)')
ax.set_ylabel('Life expectancy at birth (years)')

ax.tick_params(labelsize=14)

ax.set_xlim((min_x - 0.03*(max_x - min_x)), 
            (max_x + 0.03*(max_x - min_x)))

lgnd = plt.legend(loc='upper right')
lgnd.legendHandles[0]._sizes = [40]
lgnd.legendHandles[1]._sizes = [40]
lgnd.legendHandles[2]._sizes = [40]
fig.set_size_inches(16.5, 10.5)
plt.grid()

# %%
filename = os.path.join('Data', 'SYB62_T11_Expenditure on Health.csv')
health_df = pd.read_csv(filename, encoding='ISO-8859-1', skiprows=1)
health_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                             'Unnamed: 1': 'Region/Country/Area'}, inplace=True)
health_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                         'Region/Country/Area': 'Country'}, inplace=True)
health_df.head(5)
# Out:
#    Country ID      Country  Year                                 Series  \
# 0           4  Afghanistan  2005  Current health expenditure (% of GDP)
# 1           4  Afghanistan  2010  Current health expenditure (% of GDP)
# 2           4  Afghanistan  2014  Current health expenditure (% of GDP)
# 3           4  Afghanistan  2015  Current health expenditure (% of GDP)
# 4           4  Afghanistan  2016  Current health expenditure (% of GDP)
#
#      Value Footnotes                                             Source
# 0   9.9483       NaN  World Health Organization (WHO), Geneva, WHO G...
# 1   8.5697       NaN  World Health Organization (WHO), Geneva, WHO G...
# 2   9.5289       NaN  World Health Organization (WHO), Geneva, WHO G...
# 3  10.0940       NaN  World Health Organization (WHO), Geneva, WHO G...
# 4  10.1987       NaN  World Health Organization (WHO), Geneva, WHO G...

# %%
gdpfilename = os.path.join('Data', 'SYB62_T13_201904_GDP_and_GDP_Per_Capita.csv')
gdp_df = pd.read_csv(gdpfilename, encoding='ISO-8859-1', skiprows=1)
gdp_df.rename(columns={'Region/Country/Area': 'Region/Country/Area ID',
                             'Unnamed: 1': 'Region/Country/Area'}, inplace=True)
gdp_df = gdp_df[839:]      # remove data per region and just keep data per country
gdp_df.rename(columns={'Region/Country/Area ID': 'Country ID',
                         'Region/Country/Area': 'Country'}, inplace=True)
gdp_df.head()
# Out:
#      Country ID      Country  Year  \
# 839           4  Afghanistan  2010
# 840           4  Afghanistan  2015
# 841           4  Afghanistan  2016
# 842           4  Afghanistan  2017
# 843           4  Afghanistan  1985
#
#                                              Series   Value Footnotes  \
# 839  GDP in current prices (millions of US dollars)  16,078       NaN
# 840  GDP in current prices (millions of US dollars)  20,608       NaN
# 841  GDP in current prices (millions of US dollars)  20,235       NaN
# 842  GDP in current prices (millions of US dollars)  21,993       NaN
# 843                     GDP per capita (US dollars)     282       NaN
#
#                                                 Source
# 839  United Nations Statistics Division, New York, ...
# 840  United Nations Statistics Division, New York, ...
# 841  United Nations Statistics Division, New York, ...
# 842  United Nations Statistics Division, New York, ...
# 843  United Nations Statistics Division, New York, ...

# %%
import numpy as np
import matplotlib.pyplot as plt

health_gdp_df = health_df[health_df['Series'] == 'Current health expenditure (% of GDP)']
health_gdp_df = health_gdp_df.loc[:, ['Country', 'Year', 'Value']]
health_gdp_df.rename(columns={'Value': 'health expenditure (% of GDP)'}, inplace=True)
health_gdp_df.set_index(['Country', 'Year'], inplace=True)

gdp_percapita_df = gdp_df[gdp_df['Series'] == 'GDP per capita (US dollars)']
gdp_percapita_df = gdp_percapita_df.loc[:, ['Country', 'Year', 'Value']]
gdp_percapita_df.rename(columns={'Value': 'GDP per capita (US dollars)'}, inplace=True)
gdp_percapita_df.set_index(['Country', 'Year'], inplace=True)

summary_df = health_gdp_df.join(life_expectancy_df, how='inner')
summary_df = summary_df.join(estimated_population_df, how='inner')
summary_df = summary_df.join(gdp_percapita_df, how='inner')
summary_df.reset_index(inplace=True)
summary_df['health expenditure (% of GDP)'] = summary_df['health expenditure (% of GDP)'].transform(lambda x: x.replace(',', '')).apply(float)
summary_df['GDP per capita (US dollars)'] = summary_df['GDP per capita (US dollars)'].transform(lambda x: x.replace(',', '')).apply(float)

summary_df['health expenditure per Capita (US dollars)'] = summary_df['health expenditure (% of GDP)']*summary_df['GDP per capita (US dollars)'] / 100

summary_df['health expenditure per Capita (US dollars)'] = summary_df['health expenditure per Capita (US dollars)'].map("{:.1f}".format)


min_x = float(summary_df["health expenditure per Capita (US dollars)"].min())
max_x = float(summary_df["health expenditure per Capita (US dollars)"].max())


fig, ax = plt.subplots()

ax.scatter(y=summary_df[summary_df['Year'] == 2005]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2005]['health expenditure per Capita (US dollars)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2005]['Population mid-year estimates (millions)'],
           color='yellow', marker='o', edgecolor='black', label='2005')
ax.scatter(y=summary_df[summary_df['Year'] == 2010]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2010]['health expenditure per Capita (US dollars)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2010]['Population mid-year estimates (millions)'],
           color='red', marker='o', edgecolor='black', label='2010')
ax.scatter(y=summary_df[summary_df['Year'] == 2015]['Life expectancy at birth for both sexes (years)'],
           x=summary_df[summary_df['Year'] == 2015]['health expenditure per Capita (US dollars)'].apply(pd.to_numeric),
           s=summary_df[summary_df['Year'] == 2015]['Population mid-year estimates (millions)'],
           color='orange', marker='o', edgecolor='black', label='2015')

ax.set_title('Life Expectancy vs health expenditure per Capita (US dollars)\n(Note: Bubble Size Indicates Country Population)')
ax.set_xlabel('health expenditure per Capita (US dollars)')
ax.set_ylabel('Life expectancy at birth (years)')


ax.tick_params(labelsize=14)

ax.set_xlim((min_x - 0.15*(max_x - min_x)), 
            (max_x + 0.15*(max_x - min_x)))

lgnd = plt.legend(loc='upper right')
lgnd.legendHandles[0]._sizes = [40]
lgnd.legendHandles[1]._sizes = [40]
lgnd.legendHandles[2]._sizes = [40]
fig.set_size_inches(16.5, 10.5)
plt.grid()
